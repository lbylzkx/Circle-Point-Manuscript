# %%
import numpy as np
import matplotlib.pyplot as plt
from arc import *
from waterlily import *


for n in range(7, 0, -1):
    for i in range(0, 13):
        onepetal(n, i*np.pi/6, color[n])

# %%
import numpy as np
import matplotlib.pyplot as plt
from arc import *
from waterlily import *

fig, ax = plt.subplots(figsize=(12, 12))
ax.set_aspect('equal')

# for n in range(7, 3, -1):
for i in range(0, 25):
    onepetal(8, i*np.pi/12, 'r')
for i in range(0, 25):
    onepetal(7, i*np.pi/12, 'orange')
for i in range(0, 25):
    onepetal(6, i*np.pi/12, 'yellow')
for i in range(0, 25):
    onepetal(5, i*np.pi/12, 'g')
for i in range(0, 25):
    onepetal(4, i*np.pi/12, 'cyan')
for i in range(0, 25):
    onepetal(3, i*np.pi/12, 'b')
for i in range(0, 25):
    onepetal(2, i*np.pi/12, 'purple')
plt.axis('equal')
plt.axis('off') 
plt.show()

# %%
fig.savefig('./images/waterlily_24_12.jpg', dpi=1200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from arc import *
from waterlily import *
from arc_fill import *

for n in range(7, 0, -1):
    for i in range(0, 13):
        onepetal(n, i*np.pi/6, color[n])

# %%
import numpy as np
import matplotlib.pyplot as plt
from arc import *
from waterlily import *

fig, ax = plt.subplots(figsize=(12, 12))
plt.axis('off')

for n in range(3, 0, -1):
    for i in range(0, 13):
        onepetal(n, i*np.pi/6+np.pi/12,'r')

# %%
fig.savefig('./images/waterlily_print.png', dpi=1200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from arc import *
from waterlily import *

fig, ax = plt.subplots(figsize=(12, 12))
plt.axis('off')
for i in range(3):
    lotus_3(np.sqrt(3)**i,12,i*np.pi/6,'r')

# %%
fig.savefig('./images/lotus_3_print.png', dpi=1200)

# %%
from arc import *
import numpy as np
import matplotlib.pyplot as plt
from arc import *

def onearc_lotus_n(center, r, n, theta, color='b'):
    # arc_degree(center, r, theta, theta+2*np.pi*(n-2)/n, color)
    # (n-2)/n个圆弧
    arc_degree_inverse(center, r, theta, theta+2*np.pi*(n-2)/n, color)


def lotus_n(r, n, theta=0, color='b'):
    for i in range(0, n+1):
        onearc_lotus_n((r*np.cos(i*2*np.pi/n+np.pi/2+theta),
                       r*np.sin(i*2*np.pi/n+np.pi/2+theta)), r, n, theta+i*2*np.pi/n, color)


lotus_n(1, 5, 0)
plt.show()
