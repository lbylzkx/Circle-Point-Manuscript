# %%
import numpy as np
import matplotlib.pyplot as plt 
# from circle import *
from kathara import *


fig, ax = plt.subplots(figsize=(6, 6))
ax.set_facecolor('black')
# plt.figure(facecolor='black')
Kathara_Pro_C(2, np.sqrt(2))
plt.axis('equal')
plt.axis('off')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
from kathara import *

plt.figure(facecolor='black')
Kathara_C(2)
plt.axis('equal')
plt.axis('off')
plt.show()
plt.savefig('./images/kathara2.png', dpi=1200)
