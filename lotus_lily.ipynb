# %%
import numpy as np
import matplotlib.pyplot as plt
from arc import *
from lotus import *
from waterlily import *
from lotus_lily import *

fig, ax = plt.subplots(figsize=(12, 12))
ax.set_aspect('equal')

for n in range(12, 0, -1):
    for i in range(0, 13):
        onepetal_spiral(n, i*np.pi/6, color1[i])
plt.plot(0,0,'white')
plt.axis('equal')
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/lotus_spiral_12_l.png', dpi=1200)

# %%
import numpy as np
import matplotlib.pyplot as plt
from arc import *
from lotus import *
from waterlily import *
from lotus_lily import *

fig, ax = plt.subplots(figsize=(12, 12))
ax.set_aspect('equal')
color2=['r','gold','b']*8
for n in range(7, 0, -1):
    for i in range(0, 13):
        onepetal_ll(n, i*np.pi/6, color2[i])
plt.scatter(0, 0, s=100, color='white', linewidth=2.0)
# plt.plot(0,0,'white')
plt.axis('equal')
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/lotus_lily_g_7.png', dpi=1200)

# %%
import matplotlib.pyplot as plt

# 创建一个图形和坐标轴
fig, ax = plt.subplots()

# 使用plot函数绘制一个简单的线段
ax.plot([0, 0], [-1, 1], linewidth=2.0, color='blue')

# 使用scatter函数绘制原点，并将其设置为加粗状态
ax.scatter(0, 0, s=100, color='gold', linewidth=2.0)

# 显示图形
plt.show()
