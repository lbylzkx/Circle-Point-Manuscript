# %% [markdown]
# # 点

# %%
from points import *
from connect_points import *
from circle import *
fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect('equal')
plt.axis("off")
# n:n边形点即圆周上均匀分布n个点
# m:m层
m = 6
n = 4
N=24
theta = 0
theta1 = -np.pi/6
theta2 = -np.pi/3
color = "#00f"
size = 12

# draw_n_points_array_outer(n, m, theta, color, size)
# draw_n_points_array_outer(n, m, theta1, color, size)
# draw_n_points_array_outer(n, m, theta2, color, size)

# draw_points(n_points(6, 1/2, np.pi), 'g', 300)
# draw_n_points_array(3, 2, 0, "b",50)

draw_points(n_points_array_outer_rotate(n, m, np.pi/6, theta), color, 12)
draw_points(n_points_array_outer_rotate(n, m, np.pi/3, theta), color, 12)
draw_points(n_points_array_outer_rotate(n, m, np.pi, theta), color, 12)
# for i in range(N):
#     draw_points(n_points_array_outer_rotate(n, m, np.pi, i*np.pi/N+theta), color, 12)

# draw_points(n_points_array_outer(4, 3, 0))
# draw_points(n_points_array_inner(4, 3, 0),'r')
# draw_points(n_points_array_inner(12, 3, -np.pi/3),'g')
# connect_all(n_points_array_outer(4, 3, 0))
# circle((0,0),1)
plt.axis("equal")
# image_path = f'./images/Publication/points_{m}_{n}.jpg'
# fig.savefig(image_path, dpi=400)
plt.show()

# %%
fig.savefig("./images/Publication/points_12_4_r2.jpg", dpi=400)

# %%
from points import *
from circle import *

fig, ax = plt.subplots(figsize=(2, 2))
ax.set_aspect("equal")
plt.axis("off")
draw_points([[0, 0]], "#0f0")
# circle((0, 0), 1,'#0f0')

# %%
fig.savefig("./images/Publication/point_p.jpg", dpi=200)

# %% [markdown]
# # 线

# %%
from connect_points import *

fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect("equal")
plt.axis("off")
N = 24
R = 1
colorl = "#0f0"
colorp = "#00f"
points = n_points(N, R)
# connect(points,color)
# connect_with_points(points,colorp,colorl)
# connect_all(points,color)
connect_all_with_points(points, colorp, colorl)
image_path = f"./images/Publication/line_{N}.jpg"
fig.savefig(image_path, dpi=400)
plt.axis("equal")
plt.show()

# %%
from points import *
from connect_points import *

fig, ax = plt.subplots(figsize=(4, 4))
# ax.set_aspect('equal')
plt.axis("off")

# connect_all(n_points_array(8, 3, 0))
# draw_n_points_array(8, 3, 0, 'b')

connect_all(n_points_array_inner(12, 2, -np.pi / 3))
# connect_all(n_points_array_outer(8, 3, np.pi/3))
plt.axis("equal")
plt.show()

# %%
from points import *
from connect_points import *
from circle import *

fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect("equal")
plt.axis("off")
# n:n边形点即圆周上均匀分布n个点
# m:m层
m = 5
n = 6
theta = 0
theta1 = -np.pi / 6
theta2 = -np.pi / 3
alpha = 0
color = "#00f"
size = 12
M = 72
N = 6
# draw_n_points_array_outer(n, m, theta, color, size)
# draw_n_points_array_outer(n, m, theta1, color, size)
# draw_n_points_array_outer(n, m, theta2, color, size)

# draw_points(n_points(6, 1/2, np.pi), 'g', 300)
# draw_n_points_array(3, 2, 0, "b",50)

# draw_points(n_points_array_outer_rotate(n, m, 0, theta), color, 32)
# connect_all(n_points_array_outer_rotate(n, m, 0,theta))

# draw_points(n_points_array_outer(4, 3, 0))
# draw_points(n_points_array_inner(4, 3, 0),'r')
# draw_points(n_points_array_inner(12, 3, -np.pi/3),'g')
# connect_all(n_points_array_outer(4, 3, 0))
# circle((0,0),1)


multi_polygon(N, M, 0, 0)
plt.axis("equal")
image_path = f"./images/Publication/multi_polygon_call_colorful_{M}_{N}.jpg"
fig.savefig(image_path, dpi=400)
plt.show()

# %%
from points import *
from connect_points import *
from circle import *
fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect('equal')
plt.axis("off")
connect_all(n_points_array_outer(7, 3, np.pi/7), 0)


# points=n_points(6, 1, 0)
# points+=n_points(6, 2, 0)
# points+=n_points(6, 3, 0)
# connect_all(points)
# connect_like_metatron(8, 3, 0)
fig.savefig("./images/Publication/connect_like_krystal_7_3.jpg", dpi=400)
plt.show()

# %%
fig.savefig("./images/Publication/connect_like_metatron_8_3.jpg", dpi=400)

# %% [markdown]
# # 波(Waves)

# %% [markdown]
# ## 等比波

# %%
from waves import *

fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect('equal')
plt.axis('off')
# A:振幅Amplitude
# F:频率Frequency
# P:相位Phase
A = complex(np.e, np.pi)
# A = np.e
F = 6
P = 12
theta = 0
color = '#0f0'
backcolor = '#fff'
fig.patch.set_facecolor(backcolor)
wave_circle_pro(A, F, P, color, theta, 1)
image_path = f'./images/Publication/p_{A}_{F}_{P}.jpg'
fig.savefig(image_path, dpi=400)
plt.show()
# Out:
# c:\Users\lbylzk\anaconda3\Lib\site-packages\matplotlib\cbook.py:1699: ComplexWarning: Casting complex values to real discards the imaginary part
#   return math.isfinite(val)
# c:\Users\lbylzk\anaconda3\Lib\site-packages\matplotlib\cbook.py:1345: ComplexWarning: Casting complex values to real discards the imaginary part
#   return np.asarray(x, float)

# %%
fig.savefig("./images/Publication/1_6_12.jpg", dpi=300)

# %%
from waves import *

fig, ax = plt.subplots(figsize=(3, 3))
ax.set_aspect("equal")
plt.axis("off")
circle((0, 0), 1, "g")

# %%
fig.savefig("./images/Publication/circle.jpg", dpi=300)

# %% [markdown]
# ## 等差波

# %%
from circle import *

fig, ax = plt.subplots(figsize=(3, 3))
ax.set_aspect("equal")
A = 1
F = 1
P = 12
theta = np.pi / 2
np.pi / 2
color = "#f00"
colors = [
    "r",
    "orange",
    "yellow",
    "green",
    "blue",
    "purple",
    "r",
    "orange",
    "yellow",
    "green",
    "blue",
    "purple",
] * 2

ConcentricCircles((0, 0), F, A, 1, "#f00")

for i in range(P + 1):
    # ConcentricCircles(((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), 2, 1, color[i])
    ConcentricCircles_o(
        ((np.cos(2 * i * np.pi / P + theta)), np.sin(2 * i * np.pi / P + theta)),
        F,
        A,
        0.5,
        color,
    )
# ConcentricCircles(((np.cos(2*np.pi/P+np.pi/2)),
#                    np.sin(2*np.pi/P+np.pi/2)), F, A, 1, 'r')
# ConcentricCircles((0, 0), F, A, np.sqrt(2), '#00f')
plt.axis("off")
plt.show()

# %%
fig.savefig("./images/Publication/zhuo.jpg", dpi=400)

# %%
from circle import *

fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect("equal")
A = 1
F = 2
P = 2
theta = np.pi
color = "#0F0"
colors = ["r", "g", "b"]

ConcentricCircles_o((0, 0), F, A, 2, "r")


for i in range(P + 1):
    ConcentricCircles_o(
        ((np.cos(2 * i * np.pi / P + theta)), np.sin(2 * i * np.pi / P + theta)),
        F,
        A,
        1,
        colors[i],
    )
plt.axis("off")
plt.show()

# %% [markdown]
# $x=\frac{\sqrt5-1}{2}或\frac{\sqrt5+1}{2}$

# %% [markdown]
# # 花(Flowers)

# %% [markdown]
# ## 睡莲(Water lily)

# %% [markdown]
# ### 圆弧绘制

# %%
from n_lily import *
from circle import *

fig, ax = plt.subplots(figsize=(12, 12))
ax.set_aspect("equal")
plt.axis("off")
# M:花层数
# N：一层花瓣数
M = 3
# N=int(input("请输入："))
N = 12
color1 = "#ff0"
color2 = "gold"
fig.patch.set_facecolor("#fff")
# circle((0, 0), np.sqrt(2*np.cos(np.pi/N))**2, color1)
# circle((0, 0), np.sqrt(2*np.cos(np.pi/N))**4, color1)
lily_n_flower(M, N, color1)
# lotus_n_flower_similar(M, N, color1)

lily_n_flower_with_feild(M, N, color1, color2)
# lotus_n_flower_similar_with_feild(M, N, color1,color2)
plt.show()

# %%
fig.savefig("./images/Design/flower_3_12_gold.svg", dpi=800)

# %%
fig.savefig("./images/Publication/flower_3_12.jpg", dpi=400)

# %%
fig.savefig("./images/Publication/flower_withfield_3_12.jpg", dpi=400)

# %% [markdown]
# ### 花瓣绘制

# %%
from n_lily import *

fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect("equal")
plt.axis("off")
# fig.patch.set_facecolor('#00f')
# M:花层数
# N：一层花瓣数
# n:花瓣基数
M = 3
N = 8
n = 8
color = "#f0f"
colors = ['#f0f', '#0f0', '#ff0', '#0f0', '#f00', 'b']*8
colors1 = ['r', 'orange', 'yellow', 'green', 'blue', 'purple']
theta = 2 * np.pi / N
for j in range(M + 1, 1, -1):
    for i in range(0, N):
        one_petal(
            (0, 0),
            np.sqrt(2 * np.cos(np.pi / n)) ** (2 * j - 1),
            n,
            2 * i * np.pi / N + (j - 1) * np.pi / N + theta,
            colors[i],
        )


# def one_layer_flower_by_petal(center, R, n, theta, color):
#     for i in range(0, n):
#         one_petal(center, R, n, 2 * i * np.pi / n + theta, color)


# for j in range(M, 0,-1):
#     one_layer_flower_by_petal((0, 0), np.sqrt(
#         2 * np.cos(np.pi / n)) ** (2 * j), N, 0, colors[j])
# print(colors[j])

# for j in range(1, M + 1):
#     flower_by_petal((0, 0), np.sqrt(j), M, N, n, (j-1)*np.pi/N/2, 'b')
# flower_by_petal((0, 0), np.sqrt(4), M, N, n, np.pi/N,'b')
# image_path = f'./images/Publication/flower_by_petal_{M}_{N}_{n}.jpg'
# fig.savefig(image_path, dpi=400)

plt.show()

# %%
fig.savefig("./images/Publication/flower_by_petal_35_35_5.jpg", dpi=1200)

# %%
from n_lily import *

fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect("equal")
plt.axis("off")
# fig.patch.set_facecolor('#00f')
# M:花层数
# N：一层花瓣数
# n:花瓣基数
M = 5
N = 9
n = 9
color = "#f0f"
colors = ['#f0f', '#0f0', '#ff0', '#0f0', '#f00', 'b']*8
colors1 = ['r', 'orange', 'yellow', 'green', 'blue', 'purple']
theta = np.pi /8
for j in range(M + 1, 1, -1):
    for i in range(0, N):
        one_petal(
            (0, 0),
            np.sqrt(np.sqrt(2)) ** (2 * j - 1),
            n,
            2 * i * np.pi / N + (j - 1) * np.pi / N + theta,
            colors[i],
        )

# %%
fig.savefig("./images/Design/flower_9_colorful.jpg", dpi=800)

# %% [markdown]
# ### 带填充花

# %%
from n_lily import *

fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect("equal")
plt.axis("off")
# one_layer_flower_by_petal_fill((0, 0), 1, 9, 0, '#0f0', 'b')
# flower_by_petal_fill((0, 0), 1, 2, 12, 4, 0, '#f99', '#f00')
# M:花层数
# N：一层花瓣数
# n:花瓣基数
M = 6
N = 12
n = 4
color = '#fff'
colors = ['#f0f', '#0f0', '#ff0', '#0f0', '#f00', 'b']*8
colors1 = ['white','purple','#f0f', '#00f','#0ff', '#0f0', '#ff0', '#f00']
theta = 2 * np.pi / N
for j in range(M + 1, 1, -1):
    for i in range(0, N):
        one_petal_fill(
            (0, 0),
            np.sqrt(2 * np.cos(np.pi / n)) ** (2 * j - 1),
            n,
            2 * i * np.pi / N + (j - 1) * np.pi / N + theta,
            colors1[j],color
        )
plt.show()

# %%
fig.savefig("./images/Publication/waterlily_with_petal_color.jpg", dpi=1200)

# %% [markdown]
# ## 荷花(Lotus)

# %%
from rodincoil import *
from n_lotus import *
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
plt.axis('off')

R = 1
r = 2
N = 36
n = 6
theta = 0
color = '#f00'
colors = ['#f0f', '#0f0', '#ff0', '#0f0', '#f00', 'b']*8
circle((0, 0), 1, '#0f0')
lotus_flower_by_petal((0, 0), R, r, N, n, theta, color)
# lotus_flower_by_petal_colorful((0, 0), R, r, N, n, theta, colors)
# lotus_flower_by_petal((0, 0), 1, 3, 12, 3, 0, 'b')
# lotus_flower_by_petal_colorful((0, 0), 1, 3, 12, 3, 0, colors)
image_path = f'./images/Publication/lotus_{R}_{r}_{N}_{n}.jpg'
fig.savefig(image_path, dpi=400)

# %%
fig.savefig('../Design/glasses cloth/lotus_r.jpg', dpi=800)

# %%
from rodincoil import *
from n_lotus import *
fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect('equal')
plt.axis('off')
R = 1
r = 2
N = 36
color = 'b'
theta = np.pi/2
colors = ['#f0f', '#0f0', '#ff0', '#0f0', '#f00', 'b']*8
rodincoil_colorful(R, r, N, colors, theta)
# rodincoil(1, 2, 3, 'b',np.pi/2)
circle((0, 0), 1, 'g')
image_path = f'./images/Publication/rodincoil_colorful_{R}_{r}_{N}.jpg'
fig.savefig(image_path, dpi=400)

# %%
fig.savefig("./images/Publication/rodincoil_1_2_12.jpg", dpi=400)

# %% [markdown]
# # 螺线(Spirals)

# %%
from spiral import *

fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")
# plt.axhline(y=0, color='k')  # 绘制x轴
# plt.axvline(x=0, color='k')  # 绘制y轴
# lim = 5
# plt.xlim(-lim, lim)  # 设置x轴范围
# plt.ylim(-lim, lim)  # 设置y轴范围
# plt.grid(True)
plt.axis("off")


n = 12
a = 1
b = 1
cyc = 2
color = "#ff0"
theta = np.pi / 2
for i in range(n):
    # logSpiral(n, a, b, cyc, color, theta + i * 2 * np.pi / n)
    logSpiral_in(n, a, b, cyc, color, theta + i * 2 * np.pi / n)
    # logSpiral_out(n, a, b, cyc, 'b', theta + i * 2 * np.pi / n)

# logSpiral_in(n, a, b, cyc, 'r', theta)
# plt.scatter([1],[0], s=50, color='#0f0')

# %% [markdown]
# ## 马蹄莲(Calla)

# %%
from spiral import *

fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect("equal")
plt.axis("off")
fig.patch.set_facecolor("#00f")
# n:n边形
# cyc:周期(几圈)
# theta:旋转
n = 6
N = 24
cyc = 1
color = "#0ff"
if n % 2 == 1:
    theta = np.pi / n / 2
else:
    theta = np.pi / n
theta_rotate = np.pi
# n_spiral(n, cyc, color, theta)
n_spiral_rotate(n, cyc, color, theta, theta_rotate)
# 旋转叠加
# for i in range(5):
#     n_spiral_rotate(n, cyc, color, theta, theta_rotate+i*2*np.pi/N)
plt.show()

# %%
fig.savefig("./images/Publication/calla_6_24.jpg", dpi=400)

# %% [markdown]
# $y=A\sin(bx+c)+d$

# %%
from spiral import *

n = 6
cyc = 1
color = "#0ff"
theta_rotate = 0
n_spiral_rotate(n, cyc, color, theta_rotate)
plt.axis("off")
plt.axis("equal")
# Out:
# (-6.180521262002738, 6.180521262002738, -5.555751915906033, 5.5557519159060345)

# %%
fig.savefig("./images/Design/spiral_gold_right.jpg", dpi=800)

# %%
from spiral import *

fig, ax = plt.subplots(figsize=(4, 4))
ax.set_aspect("equal")
plt.axis("off")

N = 1
n = 4
cyc = 1
color = "#0f0"
colors = ["#f0f", "#00f", "#0ff", "#0f0", "#ff0", "#f00"] * 8
theta = 2 * np.pi


# def calla_petal(n, cyc, theta, color):
#     logSpiral(n, 1, 1, cyc*1.25, color, theta)
#     logSpiral(n, -1, 1, cyc*1.25, color, -theta)
# def calla_by_petal(n, cyc,N, theta,colors):
#     for i in range(N):
#         calla_petal(n, cyc, theta+i*2*np.pi/N, colors[i])
calla_by_petal(n, cyc, N, theta, colors)

# %%
from spiral import *

fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")
plt.axis("off")

N = 12
n = 4
cyc = 0.5
color = "#0f0"
colors = ["#f0f", "#00f", "#0ff", "#0f0", "#ff0", "#f00"] * 8
colors1 = ["#f0f"] * 36
theta = 2 * np.pi

# fig.patch.set_facecolor("#fff")
# def calla_petal(n, cyc, theta, color):
#     logSpiral(n, 1, 1, cyc*1.25, color, theta)
#     logSpiral(n, -1, 1, cyc*1.25, color, -theta)
# def calla_by_petal(n, cyc,N, theta,colors):
#     for i in range(N):
#         calla_petal(n, cyc, theta+i*2*np.pi/N, colors[i])
calla_by_petal(n, cyc, N, theta, colors1)

# %%
fig.savefig('../Design/glasses cloth/calla_p.jpg', dpi=800)

# %%
fig.savefig("./images/Publication/spiral_colorful_5_8_b.jpg", dpi=1200)

# %% [markdown]
# $x=\frac{\sqrt5-1}{2}或\frac{\sqrt5+1}{2}$

# %% [markdown]
# # 圈点混合(Circle Point Mix)

# %% [markdown]
# ## DNA螺旋(DNA Spiral)

# %%
from points import *
from connect_points import *
from spiral import *
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
plt.axis('off')
n = 8
R = 1
m = 12
theta = np.pi
color = 'y'
color1 = '#f0f'
colors = ['#f00', '#0f0', '#00f', '#ff0', '#f0f', '#0ff']*6
# draw_swastika(n,R,theta,color1)
draw_swastikas(n, R, m, color, theta)
# draw_swastika(2,1)
# draw_swastikas(2,1,3)
# logSpiral(4, 1, 1, 0.875, color1)
# logSpiral(4, 1, 1, 0.875, color1, np.pi/2)
# logSpiral(4, 1, 1, 0.875, color1, 3*np.pi/2)
# logSpiral(4, 1, 1, 0.875, color1, np.pi)
for i in range(24):
    logSpiral(4, 1, 1, 0.875, colors[i+1], i*np.pi/12)

# image_path = f'./images/Publication/swastika_spiral_{R}_{n}.jpg'
# fig.savefig(image_path, dpi=400)

# %%
fig.savefig('../Design/glasses cloth/DNA_w_colorful.jpg', dpi=800)

# %%
fig.savefig("./images/Publication/swastika_.jpg", dpi=1200)

# %% [markdown]
# ## 多边形-螺旋(Polygon-Spiral)

# %%
from points import *
from connect_points import *
from spiral import *
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
plt.axis('off')
n = 3
multi_polygon(n, 9, 0, 0)
for i in range(n):
    logSpiral_out(n, 1, 1, 1.3, 0, i*2*np.pi/n+np.pi/2)

# %% [markdown]
# ## 马蹄莲-睡莲(Calla-Lily)

# %%
from n_lily import *
from spiral import *
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
plt.axis('off')
color = '#f88'
colors = ['#f00', '#0f0', '#00f', '#ff0', '#f0f', '#0ff']*6
flower_by_petal((0, 0), np.sqrt(2), 3, 12, 4, 0, color)
for i in range(12):
    logSpiral_in(4, 1, 1, 0.8, color, i*np.pi/6+np.pi/24)
    logSpiral_in(4, -1, 1, 0.8, color, i*np.pi/6+np.pi/24)
    logSpiral_out(4, 1, 1, 0.562, color, i*np.pi/6+np.pi/24)
    logSpiral_out(4, -1, 1, 0.562, color, i*np.pi/6+np.pi/24)
# calla_by_petal(4, 0.562, 12, 0, colors)

# %%
fig.savefig('../Design/glasses cloth/calla_lily_w_pink.jpg', dpi=800)

# %% [markdown]
# ## 罗丹线圈-睡莲(Coil-Lily)

# %%
from n_lily import *
from rodincoil import *

fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")
plt.axis("off")
color = "#f00"
# flower_by_petal((0, 0), 1, 2, 12, 6, 0, color)

rodincoil(2, 4, 12, "#0f0", np.pi/12)
M=2
N=6
n=6
# theta = 2 * np.pi / N
# for j in range(M + 1, 1, -1):
#     for i in range(0, N):
#         one_petal(
#             (0, 0),
#             np.sqrt(2 * np.cos(np.pi / n)) ** (2 * j - 1),
#             n,
#             2 * i * np.pi / N + (j - 1) * np.pi / N + theta,
#             colors[i],
#         )
for  j in range(M):
    for i in range(0, N):
        one_petal((0, 0), np.sqrt(3), 6, 2 * i * np.pi / N + (j - 1) * np.pi / N, color)
        one_petal(
            (0, 0), np.sqrt(3) ** 2, 6, 2 * i * np.pi / N + (j - 1) * np.pi / N, color
        )
        # one_petal((0, 0), np.sqrt(3)**3, 6, 2 * i *
        #           np.pi / N + (j - 1) * np.pi / N, color)

# %%
fig.savefig('../Design/glasses cloth/3lily_w_rg.jpg', dpi=800)

# %%
fig.savefig("./images/Design/lotus_lily_colorful.jpg", dpi=800)

# %% [markdown]
# ## 荷花-睡莲(Lotus-Lily)

# %%
from n_lily import *
from n_lotus import *
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
plt.axis('off')
color = '#f88'
N = 12
# for i in range(0, N):
#     n_lotus_petal((0, 0), 2, 4, 6, 2 * i *
#               np.pi / N + np.pi /24, color)

lotus_flower_by_petal((0, 0), 2, 4, N, 6, 0, '#f88')
for i in range(0, N):
    one_petal((0, 0), np.sqrt(3), 6, 2 * i *
              np.pi / N + np.pi / N, color)
    one_petal((0, 0), np.sqrt(3)**2, 6, 2 * i *
              np.pi / N + np.pi / N, color)

# %% [markdown]
# ## 莲子荷花(Seeds-Lotus)

# %%
from points import *
from n_lotus import *
fig, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect('equal')
plt.axis('off')
N = 36
lotus_flower_by_petal((0, 0), 2, 4, N, 6, 0, '#f0f')
# draw_points(n_points(1, 0, 0), '#0f0', 48)
# draw_points(n_points(3, 0.2, 0), '#0f0', 48)
draw_points(n_points(1, 0, 0), '#0f0', 12)
draw_points(n_points(6, 0.25, np.pi/6), '#0f0', 12)
draw_points(n_points(12, 0.5, 0), '#0f0', 12)
draw_points(n_points(24, 0.75, 0), '#0f0', 12)
draw_points(n_points(36, 1, 0), '#0f0', 12)
draw_points(n_points(48, 1.25, 0), '#0f0', 12)
draw_points(n_points(60, 1.5, 0), '#0f0', 12)
draw_points(n_points(72, 1.75, 0), '#0f0', 12)
# draw_n_points_array_inner(4,12,0,'#0f0',24)
m = 12
n = 4
theta = 0
theta1 = -np.pi/6
theta2 = -np.pi/3
color = "#0f0"
size = 12
# draw_points(n_points_array_inner_rotate(n, m, np.pi/6, theta), color, 12)
# draw_points(n_points_array_inner_rotate(n, m, np.pi/3, theta), color, 12)
# draw_points(n_points_array_inner_rotate(n, m, np.pi, theta),color,12)
# draw_points(n_points_array_outer_rotate(n, 2, np.pi/6, theta),color,12)
# draw_points(n_points_array_outer_rotate(n, 2, np.pi/3, theta),color,12)
# draw_points(n_points_array_outer_rotate(n, 2, np.pi, theta),color,12)

# %%
fig.savefig('../Design/glasses cloth/lotus_with_seeds.jpg', dpi=800)
