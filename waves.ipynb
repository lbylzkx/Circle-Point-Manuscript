# %% [markdown]
# # Arithmetic Progression 等差数列

# %% [markdown]
# 公差d=1

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
d=2
m = 2
color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
         'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2

ConcentricCircles((0, 0), m,d, 1, 'g')
for i in range(13):
    # ConcentricCircles(((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), 2, 1, color[i])
    ConcentricCircles(((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), m,d,1, 'g')
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/Wave/Arithmetic/1/24.png', dpi=1200)

# %% [markdown]
# # 等比数列

# %% [markdown]
# Geometric Progression $\sqrt2$ 等比数列

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

m = 3
color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
ConcentricCircles_Pro((0, 0), m, np.sqrt(2), 1, color)
for i in range(13):
    ConcentricCircles_Pro(
        ((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), m, np.sqrt(2), 1, color)
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/Wave/Geometric/sqrt2/6_b_g.png', dpi=1200)

# %% [markdown]
# Geometric Progression $\sqrt3$ 等比数列

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

m = 21
color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
ConcentricCircles_Pro((0, 0), m, np.sqrt(3), 1, color)
for i in range(13):
    ConcentricCircles_Pro(
        ((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), m, np.sqrt(3), 1, color)
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/Wave/Geometric/sqrt3/42_b_g.png', dpi=1200)

# %% [markdown]
# Geometric Progression $\sqrt5$ 等比数列

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

m = 2
color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
ConcentricCircles_Pro((0, 0), m, np.sqrt(5), 1, color)
for i in range(13):
    ConcentricCircles_Pro(
        ((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), m, np.sqrt(5), 1, color)
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/Wave/Geometric/sqrt5/4_b_g.png', dpi=1200)

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

m = 2
color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
ConcentricCircles_Pro((0, 0), m, np.sqrt(6), 1, color)
for i in range(13):
    ConcentricCircles_Pro(
        ((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), m, np.sqrt(6), 1, color)
plt.axis('off')
plt.show()

# %% [markdown]
# Geometric Progression $\sqrt7$ 等比数列

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

m = 2
color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
ConcentricCircles_Pro((0, 0), m, np.sqrt(7), 1, color)
for i in range(13):
    ConcentricCircles_Pro(
        ((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), m, np.sqrt(7), 1, color)
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/Wave/Geometric/sqrt7/4_b_g.png', dpi=1200)

# %% [markdown]
# Geometric Progression $\sqrt(11)$ 等比数列

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

m = 2
color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
ConcentricCircles_Pro((0, 0), m, np.sqrt(11), 1, color)
for i in range(13):
    ConcentricCircles_Pro(
        ((np.cos(i*np.pi/6)), np.sin(i*np.pi/6)), m, np.sqrt(11), 1, color)
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/Wave/Geometric/sqrt11/4_b_g.png', dpi=1200)

# %% [markdown]
# # 改进

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

# A:振幅Amplitude
# F:频率Frequency
# P:相位Phase
A = 3
F = 3
P = 12

color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
# 向外
ConcentricCircles_Pro_o((0, 0), F, np.sqrt(A), 1, color)
for i in range(P+1):
    ConcentricCircles_Pro_o(
        ((np.cos(i*2*np.pi/P+np.pi/2)), np.sin(i*2*np.pi/P+np.pi/2)), F, np.sqrt(A), 1, color)
plt.axis('off')
plt.show()

# %%
from circle import *
fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
# fig.patch.set_facecolor('black')

# A:振幅Amplitude
# F:频率Frequency
# P:相位Phase
A = 3
F = 36
P = 12

color = '#0F0'
colors = ['r', 'orange', 'yellow', 'green', 'blue', 'purple',
               'r', 'orange', 'yellow', 'green', 'blue', 'purple']*2
# 双向
ConcentricCircles_Pro((0, 0), F, np.sqrt(A), 1, color)
for i in range(P+1):
    ConcentricCircles_Pro(
        ((np.cos(i*2*np.pi/P+np.pi/2)), np.sin(i*2*np.pi/P+np.pi/2)), F, np.sqrt(A), 1, color)
plt.axis('off')
plt.show()

# %%
fig.savefig('./images/Wave/Geometric/sqrt2/6_36_cyan.pdf', dpi=7200)

# %%
from waves import *

fig, ax = plt.subplots(figsize=(12, 12))
ax.set_aspect('equal')
plt.axis('off')
# A:振幅Amplitude
# F:频率Frequency
# P:相位Phase
A = complex(np.e,np.pi)
# A = np.e
F = 6
P = 36
color = '#00f'
fig.patch.set_facecolor('#f0f')
# for i in range(1,P+1):
#     wave_circle_pro(A, F, P, color)
#     image_path=f'./images/Wave/Geometric/sqrt2/18_{i}_cyan.png'
#     fig.savefig(image_path, dpi=1200)
wave_circle_pro(A, F, P, color)
plt.show()

# %%
fig.savefig('./images/Wave/Geometric/e_pi_21_12.svg', dpi=1200)

# %%
from waves import *

fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
plt.axis('off')
# A:振幅Amplitude
# F:频率Frequency
# P:相位Phase
# A = complex(0,np.pi)
A = 12
F = 12
P = 16
color = '#0ff'
for k in range(2,F+1):
    for j in range(3,A+1):
        for i in range(1, P+1):
            wave_circle_pro(A, F, P, color)
            image_path = f'./images/Wave/Geometric/sqrt{j}/{2*k}_{i}_cyan.png'
            fig.savefig(image_path, dpi=1200)
            fig.clear()

# plt.show()

# %%
from waves import *

fig, ax = plt.subplots(figsize=(9, 9))
ax.set_aspect('equal')
plt.axis('off')

A = 3
F = 1
P = 8
color = '#0ff'
wave_circle_pro(A, F, P, color)
